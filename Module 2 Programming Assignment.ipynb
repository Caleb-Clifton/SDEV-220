# %% [markdown]
# # Module 2 Programming Assignment - Loops and Conditionals
#
# Chapter 4.1, 4.2, 6.1, 6.2, 6.3
#
# Caleb Clifton
#
# Description: This notebook performs the tasks listed above using loops and conditionals

# %% [markdown]
# # Exercise 4.1
#
# Choose a number between 1 and 10 and assign it to the variable secret. Then, select another number between 1 and 10 and assign it to the variable guess. Next, write the conditional tests (if, else, and elif) to print the string 'too low' if guess is less than secret, 'too high' if greater than secret, and 'just right' if equal to secret.

# %%
# import random
import random

# set secret number
secret = random.randint(1, 10)

# accept guess
guess = int(input("Enter a guess between 1 and 10: "))

# output result. Also using a while loop to keep the cycle going until the guess is correct for fun.
while guess != secret:
    if guess > secret:
        guess = int(input("Too high. Guess again: "))
    else:
        guess = int(input("Too low. Guess again: "))

# final output once guessed correct
print("Just right!")
# Out:
# Enter a guess between 1 and 10:  5
# Too high. Guess again:  1
# Too low. Guess again:  3
# Too low. Guess again:  4
# Just right!

# %% [markdown]
# # Exercise 4.2
#
# Assign True or False to the variables small and green. Write some if/else statements to print which of these matches those choices: cherry, pea, watermelon, pumpkin.

# %%
# assign variables
small = False
green = True

# check states of small and green to determine which object fits
if small:
    if green:
        print("It's a pea!")
    else:
        print("It's a cherry!")
else:
    if green:
        print("It's a watermelon!")
    else:
        print("It's a pumpkin!")
# Out:
# It's a watermelon!

# %% [markdown]
# # Exercise 6.1
#
# Use a for loop to print the values of the list [3, 2, 1, 0].

# %%
# print all members of supplied list
for i in [3, 2, 1, 0]:
    print(i)
# Out:
# 3
# 2
# 1
# 0

# %% [markdown]
# # Exercise 6.2
#
# Assign the value 7 to the variable guess_me, and the value 1 to the variable number. Write a while loop that compares number with guess_me. Print 'too low' if number is less than guess me. If number equals guess_me, print 'found it!' and then exit the loop. If number is greater than guess_me, print 'oops' and then exit the loop. Increment number at the end of the loop.

# %%
# set starting variables
guess_me = 7
number = 1
found = False

# loop until number == guess_me or number > guess_me
while found == False:
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        found = True
    else:
        print("oops")
        break
    number += 1
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!

# %% [markdown]
# # Exercise 6.3
#
# Assign the value 5 to the variable guess_me. Use a for loop to iterate a variable called number over range(10). If number is less than guess_me, print 'too low'. If it equals guess_me, print found it! and then break out of the for loop. If number is greater than guess_me, print 'oops' and then exit the loop.

# %%
# set variables
guess_me = 5

# interative loop
for number in range(10):
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break
    else:
        print("oops")
        break
# Out:
# too low
# too low
# too low
# too low
# too low
# found it!
