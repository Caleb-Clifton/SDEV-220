# %% [markdown]
# # Chapter 3 Exercises (3.1 – 3.6)
#
# Name: Caleb Clifton
# Description: This notebook calculates seconds per hour and per day, and demonstrates division using both floating-point and integer division.

# %% [markdown]
# ## 3.1 How many seconds are in an hour?
#
# There are 60 seconds in a minute and 60 minutes in an hour.

# %%
60 * 60
# Out:
# 3600

# %% [markdown]
# ## 3.2 Assign seconds per hour to a variable

# %%
seconds_per_hour = 60 * 60
seconds_per_hour
# Out:
# 3600

# %% [markdown]
# ## 3.3 How many seconds are in a day?
#
# There are 24 hours in a day.

# %%
seconds_per_hour * 24
# Out:
# 86400

# %% [markdown]
# ## 3.4 Assign seconds per day to a variable

# %%
seconds_per_day = seconds_per_hour * 24
seconds_per_day
# Out:
# 86400

# %% [markdown]
# ## 3.5 Divide seconds per day by seconds per hour (floating-point division)

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %% [markdown]
# ## 3.6 Integer division
#
# Yes, the result agrees with the floating-point result aside from the .0. Both land on 24.

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24
